# %%
# !pip install python-crfsuite
# Out:
# Requirement already satisfied: python-crfsuite in c:\users\raghu\anaconda3\envs\cv1\lib\site-packages (0.9.9)

# %%
import pandas as pd
import pycrfsuite
from sklearn.metrics import classification_report

# %% [markdown]
# ## Question 1

# %%
def seq_generate(fp): 
    data=[]
    with open(fp, 'r', encoding='utf-8') as tsvfile:

        s=0
        temp_tok=[]
        temp_tag=[]
        seq_tok=[]
        seq_tag=[]
        for row in tsvfile:

            data.append(row)
            if row=='\n':
                seq_tok.append(temp_tok)
                seq_tag.append(temp_tag)
                temp_tok=[]
                temp_tag=[]


            else:
                row=row.strip()
                row=row.split('\t')
                temp_tok.append(row[0])
                temp_tag.append(row[1])
    return seq_tok,seq_tag

# %%
train_tokens, train_tags = seq_generate('ncbi-disease-master/conll/train.tsv')
test_tokens, test_tags = seq_generate('ncbi-disease-master/conll/test.tsv')

print("number of sequence in train",len(train_tokens))
print("number of sequence in tag",len(test_tokens))

print("train tokens 1st sequence ")
print( train_tokens[0])
print("train tags 1st sequence ")
print( train_tags[0])
# Out:
# number of sequence in train 5432
# number of sequence in tag 940
# train tokens 1st sequence
# ['Identification', 'of', 'APC2', ',', 'a', 'homologue', 'of', 'the', 'adenomatous', 'polyposis', 'coli', 'tumour', 'suppressor', '.']
# train tags 1st sequence
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Disease', 'I-Disease', 'I-Disease', 'I-Disease', 'O', 'O']

# %% [markdown]
# ## Question 2

# %%
b_count=0
i_count=0
o_count=0
for i in train_tags:
    for j in i:
        if(j=='I-Disease'):
            i_count=i_count+1
        if(j=='B-Disease'):
            b_count=b_count+1
        if(j=='O'):
            o_count=o_count+1

# %%
print("count of I-Disease ",i_count)
print("count of B-Disease ",b_count)
print("count of O         ",o_count)
# Out:
# count of I-Disease  6122
# count of B-Disease  5145
# count of O          124819

# %%
# freq_tag=pd.DataFrame(columns=['words','counts','tags'])
dict_tags={}
for i in range(0,len(train_tokens)):
    
    for j in range(len(train_tokens[i])):
        if(train_tags[i][j]=='B-Disease' or train_tags[i][j] == 'I-Disease'):
            if(train_tokens[i][j] not in dict_tags.keys()):
                dict_tags[train_tokens[i][j]]=1
            if(train_tokens[i][j] in dict_tags.keys()):
                dict_tags[train_tokens[i][j]]=dict_tags[train_tokens[i][j]]+1

# %%
decending_order_cnt=sorted(list(dict_tags.values()), reverse=True)

# %%
common_words=[]
for i in decending_order_cnt[:20]:
    for k in dict_tags.keys():
        if(dict_tags[k]==i):
            common_words.append(k)

# %%
print("the 20 common words are")
common_words
# Out:
# the 20 common words are
# ['-',
#  'deficiency',
#  'syndrome',
#  'cancer',
#  'disease',
#  'of',
#  'dystrophy',
#  'breast',
#  'ovarian',
#  'X',
#  'and',
#  'DM',
#  'and',
#  'DM',
#  'ALD',
#  'DMD',
#  'APC',
#  'disorder',
#  'muscular',
#  'disorder',
#  'muscular',
#  'G6PD',
#  'linked',
#  'the']

# %%
import nltk
from nltk import word_tokenize, pos_tag

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\raghu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\raghu\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ## Question 3

# %%
def feature_words(seq,pos):
    feature_vect=[]
    low=seq[pos].lower()
    
    feature_vect.append("w0.lower="+str(low))
    
    suff=seq[pos][-3:]
    feature_vect.append("w0.suffix3="+str(suff))
    if(pos==0):
        feature_vect.append("w-1.previous=BOS")
    else:
        feature_vect.append("w-1.previous="+seq[pos-1].lower())
    if(pos==len(seq)-1):
        feature_vect.append("w1.post=EOS")
    else:
        feature_vect.append("w1.post="+seq[pos+1].lower())
        
    tags = pos_tag([str(seq[pos])])
    feature_vect.append("w0.pos="+tags[0][1])
    feature_vect.append("w0.tit="+str(seq[pos].istitle()))
    return feature_vect

# %%
# !pip install textblob
# !pip install spacy

# %%
features_tok_train=[]
for i in train_tokens:
    temp=[]
    for j in range(0,len(i)):
        fun_return=feature_words(i,j)
        temp.append(fun_return)
    features_tok_train.append(temp)
features_tok_test=[]       
for i in test_tokens:
    temp=[]
    for j in range(0,len(i)):
        fun_return=feature_words(i,j)
        temp.append(fun_return)
    features_tok_test.append(temp)

# %%
features_tok_train[0][:3]
# Out:
# [['w0.lower=identification',
#   'w0.suffix3=ion',
#   'w-1.previous=BOS',
#   'w1.post=of',
#   'w0.pos=NN',
#   'w0.tit=True'],
#  ['w0.lower=of',
#   'w0.suffix3=of',
#   'w-1.previous=identification',
#   'w1.post=apc2',
#   'w0.pos=IN',
#   'w0.tit=False'],
#  ['w0.lower=apc2',
#   'w0.suffix3=PC2',
#   'w-1.previous=of',
#   'w1.post=,',
#   'w0.pos=NN',
#   'w0.tit=False']]

# %% [markdown]
# ## Question 4

# %%
trainer = pycrfsuite.Trainer(verbose=False)

for xseq, yseq in zip(features_tok_train, train_tags):
    trainer.append(xseq, yseq)

# %%
trainer.set_params({
    'c1': 1.0,   # coefficient for L1 penalty
    'c2': 1e-3,  # coefficient for L2 penalty
    'max_iterations': 50,  # stop earlier

    # include transitions that are possible, but not observed
    'feature.possible_transitions': True
})

# %%
trainer.params()
# Out:
# ['feature.minfreq',
#  'feature.possible_states',
#  'feature.possible_transitions',
#  'c1',
#  'c2',
#  'max_iterations',
#  'num_memories',
#  'epsilon',
#  'period',
#  'delta',
#  'linesearch',
#  'max_linesearch']

# %%
trainer.train('conll2002-esp.crfsuite')

# %%
# !dir /B .\conll2002-esp.crfsuite
# Out:
# conll2002-esp.crfsuite

# %%
trainer.logparser.last_iteration
# Out:
# {'num': 50,
#  'scores': {},
#  'loss': 5634.827547,
#  'feature_norm': 69.356852,
#  'error_norm': 403.67243,
#  'active_features': 3147,
#  'linesearch_trials': 1,
#  'linesearch_step': 1.0,
#  'time': 0.1}

# %%
print(len(trainer.logparser.iterations), trainer.logparser.iterations[-1])
# Out:
# 50 {'num': 50, 'scores': {}, 'loss': 5634.827547, 'feature_norm': 69.356852, 'error_norm': 403.67243, 'active_features': 3147, 'linesearch_trials': 1, 'linesearch_step': 1.0, 'time': 0.1}

# %%
tagger = pycrfsuite.Tagger()
tagger.open('conll2002-esp.crfsuite')

# %%
y_pred = [tagger.tag(xseq) for xseq in features_tok_test]

# %%
true_labels = [label for labels in test_tags for label in labels]
predicted_labels_flat = [label for labels in y_pred for label in labels]

# %%
len(true_labels)
# Out:
# 24497

# %%
report = classification_report(true_labels, predicted_labels_flat, labels=["B-Disease", "I-Disease", "O"])


print(report)
# Out:
#               precision    recall  f1-score   support
#
#    B-Disease       0.85      0.72      0.78       960
#    I-Disease       0.82      0.78      0.80      1087
#            O       0.98      0.99      0.99     22450
#
#     accuracy                           0.97     24497
#    macro avg       0.88      0.83      0.85     24497
# weighted avg       0.97      0.97      0.97     24497

# %% [markdown]
# ## Question 5

# %%
from collections import Counter

# %%
tagger = pycrfsuite.Tagger()
tagger.open('conll2002-esp.crfsuite')

# %%
transitions = tagger.info().transitions

# %%
transitions
# Out:
# {('O', 'O'): 2.464039,
#  ('O', 'B-Disease'): 0.140019,
#  ('O', 'I-Disease'): -8.10381,
#  ('B-Disease', 'O'): -1.633622,
#  ('B-Disease', 'B-Disease'): -5.725083,
#  ('B-Disease', 'I-Disease'): 1.438976,
#  ('I-Disease', 'O'): -1.475686,
#  ('I-Disease', 'B-Disease'): -4.160078,
#  ('I-Disease', 'I-Disease'): 1.804314}

# %%
state_features = tagger.info().state_features

# %%
state_features
# Out:
# {('w0.suffix3=ion', 'B-Disease'): -1.173761,
#  ('w0.suffix3=ion', 'I-Disease'): 0.012461,
#  ('w-1.previous=BOS', 'O'): 3.811297,
#  ('w-1.previous=BOS', 'B-Disease'): 2.73649,
#  ('w1.post=of', 'O'): 0.926477,
#  ('w1.post=of', 'B-Disease'): -0.206796,
#  ('w1.post=of', 'I-Disease'): -1.726665,
#  ('w0.pos=NN', 'O'): -1.282814,
#  ('w0.pos=NN', 'B-Disease'): 0.809206,
#  ('w0.pos=NN', 'I-Disease'): 0.04371,
#  ('w0.tit=True', 'O'): 0.571671,
#  ('w0.tit=True', 'B-Disease'): -0.698097,
#  ('w0.tit=True', 'I-Disease'): -0.874791,
#  ('w0.lower=of', 'O'): 0.076663,
#  ('w0.lower=of', 'I-Disease'): 0.723994,
#  ('w0.suffix3=of', 'O'): 0.058899,
#  ('w0.suffix3=of', 'I-Disease'): 0.734596,
#  ('w0.pos=IN', 'O'): 1.115929,
#  ('w0.pos=IN', 'B-Disease'): -1.902654,
#  ('w0.pos=IN', 'I-Disease'): -0.337155,
#  ('w0.tit=False', 'O'): 0.606712,
#  ('w0.tit=False', 'B-Disease'): -0.721301,
#  ('w0.tit=False', 'I-Disease'): -0.077017,
#  ('w-1.previous=of', 'O'): -1.740149,
#  ('w-1.previous=of', 'B-Disease'): -0.166082,
#  ('w-1.previous=of', 'I-Disease'): 0.347456,
#  ('w1.post=,', 'O'): -0.632594,
#  ('w1.post=,', 'B-Disease'): 0.076107,
#  ('w1.post=,', 'I-Disease'): 0.69834,
#  ('w0.lower=,', 'O'): 1.008232,
#  ('w0.lower=,', 'I-Disease'): -0.32302,
#  ('w0.suffix3=,', 'O'): 1.008232,
#  ('w0.suffix3=,', 'I-Disease'): -0.32302,
#  ('w1.post=a', 'O'): 0.344287,
#  ('w1.post=a', 'I-Disease'): -0.37217,
#  ('w0.pos=,', 'O'): 1.008232,
#  ('w0.pos=,', 'I-Disease'): -0.32302,
#  ('w0.lower=a', 'O'): -0.624597,
#  ('w0.lower=a', 'B-Disease'): 0.51125,
#  ('w0.lower=a', 'I-Disease'): 0.106853,
#  ('w0.suffix3=a', 'O'): 2.311623,
#  ('w-1.previous=,', 'O'): -0.411644,
#  ('w-1.previous=,', 'B-Disease'): 0.903636,
#  ('w-1.previous=,', 'I-Disease'): 0.594337,
#  ('w0.pos=DT', 'O'): 0.732203,
#  ('w0.pos=DT', 'B-Disease'): -2.312766,
#  ('w0.pos=DT', 'I-Disease'): 0.154138,
#  ('w-1.previous=a', 'O'): -0.249036,
#  ('w-1.previous=a', 'B-Disease'): 0.024776,
#  ('w-1.previous=a', 'I-Disease'): 0.219867,
#  ('w1.post=the', 'O'): -0.077062,
#  ('w1.post=the', 'B-Disease'): -2.00721,
#  ('w1.post=the', 'I-Disease'): 0.063943,
#  ('w0.lower=the', 'O'): 0.391765,
#  ('w0.lower=the', 'I-Disease'): 0.594687,
#  ('w0.suffix3=the', 'O'): 0.343567,
#  ('w0.suffix3=the', 'I-Disease'): 1.164295,
#  ('w1.post=adenomatous', 'B-Disease'): 0.863095,
#  ('w1.post=adenomatous', 'I-Disease'): -0.920906,
#  ('w0.lower=adenomatous', 'B-Disease'): 0.782037,
#  ('w0.suffix3=ous', 'O'): -0.253965,
#  ('w0.suffix3=ous', 'B-Disease'): 0.669292,
#  ('w0.suffix3=ous', 'I-Disease'): -0.019274,
#  ('w-1.previous=the', 'O'): -0.2072,
#  ('w-1.previous=the', 'B-Disease'): 0.288118,
#  ('w-1.previous=the', 'I-Disease'): 0.052489,
#  ('w1.post=polyposis', 'B-Disease'): 0.468182,
#  ('w0.pos=JJ', 'O'): -0.415576,
#  ('w0.pos=JJ', 'B-Disease'): 0.749268,
#  ('w0.pos=JJ', 'I-Disease'): -0.056284,
#  ('w0.lower=polyposis', 'O'): -0.669455,
#  ('w0.suffix3=sis', 'O'): -1.922782,
#  ('w0.suffix3=sis', 'B-Disease'): 1.225056,
#  ('w0.suffix3=sis', 'I-Disease'): 0.325396,
#  ('w-1.previous=adenomatous', 'I-Disease'): 3.272323,
#  ('w0.lower=coli', 'O'): -0.404233,
#  ('w0.lower=coli', 'I-Disease'): 0.654948,
#  ('w0.suffix3=oli', 'O'): -0.404233,
#  ('w0.suffix3=oli', 'I-Disease'): 0.654948,
#  ('w-1.previous=polyposis', 'I-Disease'): 0.022169,
#  ('w1.post=tumour', 'O'): -1.484481,
#  ('w0.pos=NNS', 'O'): -0.737988,
#  ('w0.pos=NNS', 'B-Disease'): 0.235698,
#  ('w0.pos=NNS', 'I-Disease'): 0.010405,
#  ('w0.lower=tumour', 'B-Disease'): 6.187724,
#  ('w0.lower=tumour', 'I-Disease'): 3.760891,
#  ('w0.suffix3=our', 'O'): -0.617189,
#  ('w1.post=suppressor', 'B-Disease'): 1.615341,
#  ('w0.lower=suppressor', 'O'): 1.168833,
#  ('w-1.previous=tumour', 'O'): 2.402961,
#  ('w1.post=.', 'O'): -0.502466,
#  ('w1.post=.', 'B-Disease'): -0.109299,
#  ('w1.post=.', 'I-Disease'): 0.513404,
#  ('w0.lower=.', 'O'): 1.040272,
#  ('w0.lower=.', 'I-Disease'): -0.307967,
#  ('w0.suffix3=.', 'O'): 1.040272,
#  ('w0.suffix3=.', 'I-Disease'): -0.307967,
#  ('w1.post=EOS', 'O'): 2.851727,
#  ('w1.post=EOS', 'I-Disease'): -1.248621,
#  ('w0.pos=.', 'O'): 1.041012,
#  ('w0.pos=.', 'I-Disease'): -0.308247,
#  ('w0.suffix3=The', 'O'): 1.444804,
#  ('w1.post=(', 'O'): -0.524707,
#  ('w1.post=(', 'B-Disease'): -0.135676,
#  ('w1.post=(', 'I-Disease'): 1.066824,
#  ('w0.lower=(', 'O'): 0.74608,
#  ('w0.lower=(', 'I-Disease'): -0.276461,
#  ('w0.suffix3=(', 'O'): 0.74608,
#  ('w0.suffix3=(', 'I-Disease'): -0.276461,
#  ('w0.pos=(', 'O'): 0.74608,
#  ('w0.pos=(', 'I-Disease'): -0.276461,
#  ('w0.lower=apc', 'O'): -0.672641,
#  ('w0.lower=apc', 'B-Disease'): 0.679331,
#  ('w0.suffix3=APC', 'O'): -1.810106,
#  ('w0.suffix3=APC', 'B-Disease'): 1.836272,
#  ('w-1.previous=(', 'O'): -0.38641,
#  ('w-1.previous=(', 'B-Disease'): 1.15291,
#  ('w-1.previous=(', 'I-Disease'): 0.132225,
#  ('w1.post=)', 'O'): -0.468685,
#  ('w1.post=)', 'B-Disease'): 0.587276,
#  ('w1.post=)', 'I-Disease'): 1.126439,
#  ('w0.lower=)', 'O'): 1.033509,
#  ('w0.lower=)', 'I-Disease'): -0.06152,
#  ('w0.suffix3=)', 'O'): 1.033509,
#  ('w0.suffix3=)', 'I-Disease'): -0.06152,
#  ('w-1.previous=apc', 'O'): 1.337879,
#  ('w-1.previous=apc', 'I-Disease'): -0.441963,
#  ('w0.pos=)', 'O'): 1.033509,
#  ('w0.pos=)', 'I-Disease'): -0.06152,
#  ('w-1.previous=)', 'O'): -1.877276,
#  ('w-1.previous=)', 'B-Disease'): -2.5744,
#  ('w-1.previous=)', 'I-Disease'): 0.508127,
#  ('w1.post=-', 'O'): 0.256081,
#  ('w1.post=-', 'B-Disease'): -0.044333,
#  ('w1.post=-', 'I-Disease'): -1.170877,
#  ('w0.lower=-', 'O'): 0.06805,
#  ('w0.lower=-', 'I-Disease'): 0.610578,
#  ('w0.suffix3=-', 'O'): 0.06805,
#  ('w0.suffix3=-', 'I-Disease'): 0.610578,
#  ('w0.pos=:', 'O'): 0.754555,
#  ('w0.pos=:', 'I-Disease'): 0.529161,
#  ('w-1.previous=-', 'O'): -0.366179,
#  ('w-1.previous=-', 'B-Disease'): -4.848182,
#  ('w-1.previous=-', 'I-Disease'): 0.950946,
#  ('w1.post=protein', 'O'): -0.02636,
#  ('w1.post=protein', 'I-Disease'): 0.084113,
#  ('w0.lower=protein', 'O'): 0.162995,
#  ('w0.lower=protein', 'B-Disease'): -0.116141,
#  ('w0.lower=protein', 'I-Disease'): -0.086387,
#  ('w0.suffix3=ein', 'O'): 0.597692,
#  ('w0.suffix3=ein', 'B-Disease'): -0.182822,
#  ('w0.suffix3=ein', 'I-Disease'): -0.269306,
#  ('w0.lower=controls', 'O'): 0.02791,
#  ('w0.suffix3=ols', 'O'): 0.047983,
#  ('w-1.previous=protein', 'I-Disease'): 0.577703,
#  ('w0.suffix3=ing', 'O'): 0.666914,
#  ('w0.suffix3=ing', 'I-Disease'): -0.321185,
#  ('w0.pos=VBG', 'O'): -0.017828,
#  ('w0.pos=VBG', 'B-Disease'): 0.004654,
#  ('w0.pos=VBG', 'I-Disease'): -0.473441,
#  ('w1.post=by', 'O'): 0.628218,
#  ('w1.post=by', 'I-Disease'): -0.221256,
#  ('w0.lower=by', 'O'): 0.88427,
#  ('w0.suffix3=by', 'O'): 0.737952,
#  ('w-1.previous=by', 'O'): -0.0778,
#  ('w-1.previous=by', 'B-Disease'): 0.716076,
#  ('w1.post=with', 'B-Disease'): -0.204894,
#  ('w1.post=with', 'I-Disease'): 0.489387,
#  ('w0.lower=with', 'O'): 0.731627,
#  ('w0.lower=with', 'I-Disease'): -0.03576,
#  ('w0.suffix3=ith', 'O'): 1.163369,
#  ('w0.suffix3=ith', 'I-Disease'): -0.035836,
#  ('w0.suffix3=gen', 'O'): 0.482831,
#  ('w-1.previous=with', 'O'): -0.54707,
#  ('w-1.previous=with', 'B-Disease'): 1.562555,
#  ('w0.suffix3=ase', 'O'): -0.020055,
#  ('w0.suffix3=ase', 'B-Disease'): -1.679591,
#  ('w0.suffix3=ase', 'I-Disease'): 0.487244,
#  ('w1.post=kinase', 'O'): -0.0606,
#  ('w1.post=kinase', 'B-Disease'): 0.373697,
#  ('w0.lower=kinase', 'O'): 0.751495,
#  ('w0.lower=kinase', 'I-Disease'): -0.307892,
#  ('w0.suffix3=eta', 'B-Disease'): -1.075941,
#  ('w0.suffix3=eta', 'I-Disease'): 0.002075,
#  ('w0.pos=CD', 'O'): 1.431209,
#  ('w0.pos=CD', 'I-Disease'): 1.099537,
#  ('w0.suffix3=xin', 'O'): 0.154525,
#  ('w1.post=/', 'O'): -0.384103,
#  ('w1.post=/', 'B-Disease'): 0.280198,
#  ('w1.post=/', 'I-Disease'): 0.000146,
#  ('w0.lower=/', 'O'): 1.04779,
#  ('w0.lower=/', 'I-Disease'): -0.089608,
#  ('w0.suffix3=/', 'O'): 1.04779,
#  ('w0.suffix3=/', 'I-Disease'): -0.089608,
#  ('w0.suffix3=tin', 'O'): 0.349266,
#  ('w-1.previous=/', 'O'): -0.060349,
#  ('w-1.previous=/', 'B-Disease'): 0.331957,
#  ('w-1.previous=/', 'I-Disease'): 0.000802,
#  ('w1.post=and', 'O'): -0.789344,
#  ('w1.post=and', 'B-Disease'): 0.295287,
#  ('w1.post=and', 'I-Disease'): 0.491245,
#  ('w0.lower=and', 'O'): 0.721646,
#  ('w0.lower=and', 'I-Disease'): -0.037704,
#  ('w0.suffix3=and', 'O'): 0.494677,
#  ('w0.suffix3=and', 'I-Disease'): -0.000204,
#  ('w0.pos=CC', 'O'): 1.354676,
#  ('w0.pos=CC', 'I-Disease'): -0.100883,
#  ('w0.suffix3=nin', 'O'): 0.032071,
#  ('w-1.previous=and', 'O'): -0.691731,
#  ('w-1.previous=and', 'B-Disease'): 1.090281,
#  ('w-1.previous=and', 'I-Disease'): 0.316658,
#  ('w1.post=formation', 'B-Disease'): 1.7e-05,
#  ('w0.lower=formation', 'O'): 1.260719,
#  ('w0.suffix3=ces', 'O'): 0.802756,
#  ('w0.lower=in', 'O'): 0.534239,
#  ('w0.lower=in', 'I-Disease'): -0.345286,
#  ('w0.lower=colon', 'O'): -0.948976,
#  ('w0.lower=colon', 'B-Disease'): 0.223971,
#  ('w0.suffix3=lon', 'O'): -1.050202,
#  ('w0.suffix3=lon', 'B-Disease'): 0.471317,
#  ('w-1.previous=in', 'O'): -0.30826,
#  ('w-1.previous=in', 'B-Disease'): 0.655247,
#  ('w-1.previous=in', 'I-Disease'): 0.822483,
#  ('w1.post=carcinoma', 'B-Disease'): 1.140513,
#  ('w0.suffix3=oma', 'O'): -5.413022,
#  ('w0.suffix3=oma', 'B-Disease'): 1.872679,
#  ('w0.suffix3=oma', 'I-Disease'): 1.573063,
#  ('w-1.previous=colon', 'O'): -0.447709,
#  ('w-1.previous=colon', 'I-Disease'): 0.801013,
#  ('w1.post=cells', 'B-Disease'): 0.141359,
#  ('w1.post=cells', 'I-Disease'): -0.792709,
#  ('w0.lower=cells', 'O'): 1.444126,
#  ('w0.suffix3=lls', 'O'): 1.451095,
#  ('w-1.previous=carcinoma', 'O'): 0.141072,
#  ('w-1.previous=carcinoma', 'I-Disease'): -0.152623,
#  ('w1.post=loss', 'B-Disease'): 0.040524,
#  ('w1.post=loss', 'I-Disease'): -2e-06,
#  ('w0.lower=loss', 'O'): -0.833959,
#  ('w0.lower=loss', 'I-Disease'): 0.925404,
#  ('w0.suffix3=oss', 'I-Disease'): 0.352893,
#  ('w1.post=leads', 'O'): 0.145978,
#  ('w1.post=to', 'O'): 0.459332,
#  ('w1.post=to', 'B-Disease'): 0.089206,
#  ('w1.post=to', 'I-Disease'): -0.956652,
#  ('w0.lower=to', 'O'): 0.637058,
#  ('w0.lower=to', 'I-Disease'): 0.016296,
#  ('w0.suffix3=to', 'O'): 0.525185,
#  ('w0.suffix3=to', 'I-Disease'): 0.086134,
#  ('w0.pos=TO', 'O'): 0.637058,
#  ('w0.pos=TO', 'I-Disease'): 0.016296,
#  ('w-1.previous=to', 'O'): -0.042229,
#  ('w-1.previous=to', 'B-Disease'): 0.581467,
#  ('w-1.previous=to', 'I-Disease'): -0.042277,
#  ('w1.post=accumulation', 'O'): -0.068626,
#  ('w1.post=accumulation', 'I-Disease'): 0.959715,
#  ('w0.lower=accumulation', 'O'): -0.21628,
#  ('w0.lower=accumulation', 'I-Disease'): 0.675784,
#  ('w1.post=in', 'O'): -0.189595,
#  ('w1.post=in', 'B-Disease'): 0.068918,
#  ('w1.post=in', 'I-Disease'): 0.012097,
#  ('w0.suffix3=in', 'O'): 0.369443,
#  ('w0.suffix3=in', 'I-Disease'): -0.225291,
#  ('w0.suffix3=eus', 'B-Disease'): 0.759655,
#  ('w0.suffix3=ere', 'O'): 0.957462,
#  ('w0.suffix3=ere', 'B-Disease'): 0.103266,
#  ('w-1.previous=where', 'B-Disease'): 0.018774,
#  ('w0.pos=PRP', 'O'): 0.205933,
#  ('w0.suffix3=nds', 'O'): 0.008612,
#  ('w0.suffix3=nds', 'I-Disease'): -0.00038,
#  ('w0.suffix3=tes', 'O'): 0.168906,
#  ('w0.suffix3=tes', 'I-Disease'): -0.262038,
#  ('w0.lower=transcription', 'O'): 0.001131,
#  ('w1.post=factor', 'O'): -0.018699,
#  ('w1.post=factor', 'B-Disease'): 0.020954,
#  ('w0.lower=factor', 'I-Disease'): -0.179061,
#  ('w0.suffix3=tor', 'B-Disease'): 0.022317,
#  ('w0.suffix3=tor', 'I-Disease'): -1.240272,
#  ('w-1.previous=factor', 'I-Disease'): 0.574238,
#  ('w0.pos=VBN', 'O'): 0.173965,
#  ('w0.pos=VBN', 'B-Disease'): 0.655522,
#  ('w0.pos=VBN', 'I-Disease'): -0.385984,
#  ('w1.post=[', 'I-Disease'): 1.262308,
#  ('w0.lower=[', 'O'): 0.838577,
#  ('w0.lower=[', 'I-Disease'): -0.110556,
#  ('w0.suffix3=[', 'O'): 0.838577,
#  ('w0.suffix3=[', 'I-Disease'): -0.110556,
#  ('w1.post=1', 'O'): -0.051122,
#  ('w1.post=1', 'B-Disease'): -1.788014,
#  ('w1.post=1', 'I-Disease'): 0.250666,
#  ('w0.lower=1', 'O'): -0.078756,
#  ('w0.lower=1', 'I-Disease'): 0.400393,
#  ('w0.suffix3=1', 'O'): -0.078756,
#  ('w0.suffix3=1', 'I-Disease'): 0.400393,
#  ('w0.lower=]', 'O'): 0.223801,
#  ('w0.suffix3=]', 'O'): 0.223801,
#  ('w-1.previous=1', 'O'): -0.145657,
#  ('w-1.previous=1', 'I-Disease'): 0.467177,
#  ('w1.post=2', 'I-Disease'): 0.173266,
#  ('w0.lower=2', 'O'): -0.104059,
#  ('w0.lower=2', 'I-Disease'): 0.77938,
#  ('w0.suffix3=2', 'O'): -0.104059,
#  ('w0.suffix3=2', 'I-Disease'): 0.77938,
#  ('w0.pos=RB', 'O'): 0.342178,
#  ('w0.pos=RB', 'B-Disease'): 0.00035,
#  ('w0.pos=RB', 'I-Disease'): -0.028866,
#  ('w0.lower=we', 'O'): 0.183547,
#  ('w0.suffix3=ort', 'O'): -1.3e-05,
#  ('w0.suffix3=ort', 'I-Disease'): 0.034305,
#  ('w-1.previous=we', 'O'): 0.146455,
#  ('w0.lower=genomic', 'O'): 3.353691,
#  ('w0.suffix3=mic', 'O'): -0.939464,
#  ('w0.suffix3=mic', 'B-Disease'): 2.51968,
#  ('w0.suffix3=ure', 'B-Disease'): -0.798951,
#  ('w0.suffix3=ure', 'I-Disease'): 0.481249,
#  ('w0.suffix3=ues', 'O'): 0.188863,
#  ('w0.suffix3=ian', 'O'): -0.000431,
#  ('w0.suffix3=ian', 'B-Disease'): 0.069562,
#  ('w0.suffix3=ian', 'I-Disease'): 0.13671,
#  ('w0.lower=which', 'O'): 0.37478,
#  ('w0.pos=WDT', 'O'): 0.487043,
#  ('w0.suffix3=ely', 'B-Disease'): 0.000286,
#  ('w0.suffix3=les', 'O'): 0.230335,
#  ('w1.post=domain', 'O'): 0.762339,
#  ('w0.suffix3=ain', 'O'): 0.063994,
#  ('w0.suffix3=ain', 'B-Disease'): -0.551821,
#  ('w0.suffix3=ain', 'I-Disease'): 0.02328,
#  ('w1.post=was', 'O'): -0.199846,
#  ('w1.post=was', 'I-Disease'): 0.087844,
#  ('w0.lower=was', 'B-Disease'): 1.737407,
#  ('w0.suffix3=was', 'O'): 2.789895,
#  ('w0.pos=VBD', 'O'): 1.825505,
#  ('w0.pos=VBD', 'I-Disease'): -0.313651,
#  ('w0.suffix3=lly', 'O'): -0.042059,
#  ('w0.suffix3=lly', 'B-Disease'): 0.290935,
#  ('w-1.previous=was', 'O'): 0.971807,
#  ('w-1.previous=was', 'B-Disease'): 1.292839,
#  ('w0.suffix3=zed', 'O'): 0.082885,
#  ('w0.lower=two', 'O'): 0.623886,
#  ('w0.suffix3=two', 'O'): 0.265184,
#  ('w0.lower=both', 'O'): 0.325115,
#  ('w-1.previous=both', 'O'): -0.002647,
#  ('w-1.previous=both', 'B-Disease'): 0.769086,
#  ('w1.post=are', 'O'): -0.559082,
#  ('w1.post=are', 'B-Disease'): 0.446901,
#  ('w0.lower=are', 'O'): 0.883474,
#  ('w0.suffix3=are', 'O'): 1.693505,
#  ('w0.pos=VBP', 'O'): 0.883474,
#  ('w0.suffix3=red', 'O'): -0.077578,
#  ('w0.suffix3=red', 'B-Disease'): 0.316672,
#  ('w-1.previous=are', 'B-Disease'): 0.509138,
#  ('w1.post=for', 'O'): 0.143985,
#  ('w1.post=for', 'B-Disease'): -0.479549,
#  ('w1.post=for', 'I-Disease'): 0.002948,
#  ('w0.lower=for', 'I-Disease'): 0.000545,
#  ('w-1.previous=for', 'O'): -0.851144,
#  ('w-1.previous=for', 'B-Disease'): 0.500106,
#  ('w1.post=active', 'I-Disease'): 0.841077,
#  ('w0.lower=active', 'I-Disease'): 0.006721,
#  ('w0.suffix3=ive', 'O'): 0.227688,
#  ('w0.suffix3=ive', 'B-Disease'): -0.195404,
#  ('w0.suffix3=ive', 'I-Disease'): -0.002166,
#  ('w1.post=as', 'I-Disease'): -0.024372,
#  ('w0.lower=as', 'O'): -0.543536,
#  ('w0.lower=as', 'B-Disease'): 2.070701,
#  ('w0.suffix3=as', 'O'): 1.437328,
#  ('w0.suffix3=ted', 'O'): 0.129424,
#  ('w0.suffix3=ted', 'B-Disease'): -4.1e-05,
#  ('w0.suffix3=ted', 'I-Disease'): -0.90083,
#  ('w-1.previous=as', 'O'): 0.145038,
#  ('w-1.previous=as', 'B-Disease'): 2.048181,
#  ('w-1.previous=demonstrated', 'B-Disease'): 0.721296,
#  ('w0.suffix3=ent', 'O'): 0.437159,
#  ('w0.suffix3=ent', 'B-Disease'): -0.790377,
#  ('w0.suffix3=ent', 'I-Disease'): -0.062661,
#  ('w-1.previous=using', 'O'): 0.235175,
#  ('w0.suffix3=nal', 'O'): -0.008857,
#  ('w0.suffix3=nal', 'B-Disease'): 0.176117,
#  ('w0.suffix3=nal', 'I-Disease'): 0.000241,
#  ('w0.lower=human', 'O'): 1.407965,
#  ('w0.lower=human', 'B-Disease'): -1.656477,
#  ('w0.suffix3=man', 'I-Disease'): 0.014294,
#  ('w0.pos=NNP', 'O'): -0.818173,
#  ('w0.pos=NNP', 'B-Disease'): 0.59724,
#  ('w-1.previous=human', 'B-Disease'): 0.857966,
#  ('w-1.previous=human', 'I-Disease'): -0.290736,
#  ('w1.post=chromosome', 'O'): 0.60215,
#  ('w1.post=chromosome', 'B-Disease'): -0.644429,
#  ('w1.post=chromosome', 'I-Disease'): -0.01818,
#  ('w0.lower=chromosome', 'O'): 0.199646,
#  ('w0.lower=chromosome', 'I-Disease'): -0.199423,
#  ('w0.suffix3=ome', 'O'): -0.019337,
#  ('w0.suffix3=ome', 'B-Disease'): -1.035419,
#  ('w0.suffix3=ome', 'I-Disease'): 0.582053,
#  ('w-1.previous=chromosome', 'O'): -0.203524,
#  ('w-1.previous=chromosome', 'I-Disease'): 0.621628,
#  ('w0.lower=3', 'I-Disease'): 0.059964,
#  ('w0.suffix3=3', 'I-Disease'): 0.059964,
#  ('w1.post=may', 'O'): -0.747194,
#  ('w1.post=may', 'I-Disease'): 0.470762,
#  ('w0.pos=MD', 'O'): 2.783624,
#  ('w0.suffix3=ore', 'O'): 0.319416,
#  ('w-1.previous=may', 'O'): 0.258117,
#  ('w1.post=have', 'B-Disease'): 0.199302,
#  ('w0.lower=have', 'O'): 0.270948,
#  ('w0.suffix3=ave', 'O'): 1.355242,
#  ('w0.pos=VB', 'O'): -0.129982,
#  ('w0.pos=VB', 'B-Disease'): 1.062968,
#  ('w0.pos=VB', 'I-Disease'): -0.659576,
#  ('w0.suffix3=ble', 'O'): 0.965047,
#  ('w0.suffix3=ble', 'B-Disease'): -0.000845,
#  ('w-1.previous=have', 'O'): -0.139962,
#  ('w-1.previous=have', 'B-Disease'): 0.828838,
#  ('w0.suffix3=ons', 'O'): -0.057934,
#  ('w0.suffix3=ons', 'B-Disease'): -0.515475,
#  ('w0.suffix3=ons', 'I-Disease'): 0.092122,
#  ('w0.lower=development', 'O'): 0.065906,
#  ('w1.post=cancer', 'B-Disease'): -0.025198,
#  ('w1.post=cancer', 'I-Disease'): 0.122594,
#  ('w0.lower=cancer', 'O'): -3.522968,
#  ('w0.lower=cancer', 'B-Disease'): 0.298212,
#  ('w0.lower=cancer', 'I-Disease'): 0.244511,
#  ('w0.suffix3=cer', 'O'): -2.393138,
#  ('w0.suffix3=cer', 'B-Disease'): 0.001602,
#  ('w-1.previous=cancer', 'O'): 1.96288,
#  ('w-1.previous=cancer', 'I-Disease'): -1.296466,
#  ('w0.suffix3=A', 'O'): -1.549218,
#  ('w0.suffix3=A', 'B-Disease'): 1.875992,
#  ('w0.suffix3=A', 'I-Disease'): 0.036613,
#  ('w0.lower=common', 'O'): 0.712731,
#  ('w0.suffix3=mon', 'O'): 0.838713,
#  ('w-1.previous=common', 'B-Disease'): 0.497392,
#  ('w1.post=mutation', 'O'): -0.099296,
#  ('w1.post=mutation', 'B-Disease'): 0.362118,
#  ('w0.lower=mutation', 'O'): 3.416566,
#  ('w0.suffix3=ish', 'O'): 0.632968,
#  ('w0.suffix3=can', 'O'): 0.037142,
#  ('w0.lower=hnpcc', 'B-Disease'): 2.423704,
#  ('w0.suffix3=PCC', 'B-Disease'): 2.423704,
#  ('w1.post=families', 'O'): -1.125887,
#  ('w1.post=families', 'B-Disease'): 0.874987,
#  ('w0.lower=families', 'O'): 4.602932,
#  ('w0.suffix3=ies', 'O'): -0.784297,
#  ('w0.suffix3=ies', 'B-Disease'): 0.076687,
#  ('w0.suffix3=ies', 'I-Disease'): 0.474081,
#  ('w1.post=:', 'O'): -0.747285,
#  ('w1.post=:', 'I-Disease'): 0.374028,
#  ('w0.lower=:', 'O'): 1.22454,
#  ('w0.suffix3=:', 'O'): 1.22454,
#  ('w1.post=origin', 'O'): 0.29039,
#  ('w0.lower=origin', 'O'): 0.43625,
#  ('w0.suffix3=gin', 'O'): 0.446652,
#  ('w0.lower=phenotypic', 'O'): 0.5573,
#  ('w0.suffix3=pic', 'O'): 0.926702,
#  ('w1.post=expression', 'O'): 0.433366,
#  ('w0.lower=expression', 'O'): 0.717965,
#  ('w-1.previous=phenotypic', 'I-Disease'): -0.02579,
#  ('w0.lower=specific', 'O'): 0.114056,
#  ('w0.suffix3=fic', 'O'): 0.533371,
#  ('w-1.previous=specific', 'O'): -0.000541,
#  ('w-1.previous=specific', 'B-Disease'): 0.67056,
#  ('w0.lower=colorectal', 'O'): -0.467678,
#  ('w0.lower=colorectal', 'B-Disease'): 1.673143,
#  ('w0.suffix3=tal', 'O'): -0.325384,
#  ('w0.suffix3=tal', 'B-Disease'): 0.553347,
#  ('w0.suffix3=tal', 'I-Disease'): 0.003742,
#  ('w-1.previous=colorectal', 'I-Disease'): 0.921483,
#  ('w0.lower=frequency', 'O'): 2.226332,
#  ('w0.suffix3=ncy', 'O'): -1.439748,
#  ('w0.suffix3=ncy', 'B-Disease'): 0.36646,
#  ('w0.suffix3=ncy', 'I-Disease'): 0.60329,
#  ('w1.post=germline', 'O'): -0.000823,
#  ('w1.post=germline', 'B-Disease'): 0.72342,
#  ('w0.lower=germline', 'O'): 1.524528,
#  ('w0.suffix3=ine', 'O'): -0.009394,
#  ('w0.suffix3=ine', 'B-Disease'): -0.498955,
#  ('w0.suffix3=ine', 'I-Disease'): 0.083807,
#  ('w-1.previous=germline', 'B-Disease'): 1.061579,
#  ('w1.post=gene', 'O'): -0.320189,
#  ('w1.post=gene', 'B-Disease'): 1.400097,
#  ('w1.post=gene', 'I-Disease'): -0.018562,
#  ('w0.lower=gene', 'O'): 1.653985,
#  ('w0.lower=gene', 'I-Disease'): -0.078501,
#  ('w0.suffix3=ene', 'O'): 2.01273,
#  ('w0.suffix3=ene', 'I-Disease'): -0.124349,
#  ('w-1.previous=gene', 'I-Disease'): 0.482512,
#  ('w0.suffix3=ied', 'O'): 0.153888,
#  ('w1.post=kindreds', 'O'): -1.017054,
#  ('w0.lower=kindreds', 'O'): 0.304232,
#  ('w0.suffix3=eds', 'O'): 0.512476,
#  ('w-1.previous=seven', 'O'): -1.3e-05,
#  ('w-1.previous=seven', 'B-Disease'): 0.27117,
#  ('w1.post=hereditary', 'I-Disease'): 0.210519,
#  ('w0.lower=hereditary', 'O'): -0.409322,
#  ('w0.lower=hereditary', 'B-Disease'): 0.459087,
#  ('w0.suffix3=ary', 'O'): -0.168604,
#  ('w0.suffix3=ary', 'B-Disease'): 0.448766,
#  ('w0.suffix3=ary', 'I-Disease'): -0.193689,
#  ('w0.lower=non', 'B-Disease'): -0.087512,
#  ('w0.suffix3=non', 'O'): 0.181798,
#  ('w0.suffix3=non', 'B-Disease'): -0.153921,
#  ('w-1.previous=hereditary', 'O'): -1.352716,
#  ('w-1.previous=hereditary', 'I-Disease'): 1.234171,
#  ('w1.post=syndrome', 'O'): -1.747576,
#  ('w1.post=syndrome', 'B-Disease'): -0.000496,
#  ('w1.post=syndrome', 'I-Disease'): 0.125955,
#  ('w0.lower=syndrome', 'O'): -1.924941,
#  ('w0.lower=syndrome', 'I-Disease'): 3.22723,
#  ('w-1.previous=syndrome', 'I-Disease'): -3.475651,
#  ('w1.post=>', 'O'): 0.779332,
#  ('w0.lower=>', 'O'): 0.97631,
#  ('w0.suffix3=>', 'O'): 0.97631,
#  ('w1.post=t', 'O'): -0.825151,
#  ('w1.post=t', 'B-Disease'): -0.635154,
#  ('w1.post=t', 'I-Disease'): 2.333953,
#  ('w0.lower=t', 'O'): -0.195626,
#  ('w0.lower=t', 'I-Disease'): 0.751679,
#  ('w0.suffix3=T', 'O'): -0.211845,
#  ('w0.suffix3=T', 'I-Disease'): 1.362633,
#  ('w-1.previous=>', 'O'): 1.110212,
#  ('w1.post=at', 'I-Disease'): 0.033142,
#  ('w0.lower=at', 'B-Disease'): 0.321429,
#  ('w0.suffix3=at', 'O'): 0.581254,
#  ('w-1.previous=t', 'O'): 1.618564,
#  ('w-1.previous=t', 'I-Disease'): -0.125096,
#  ('w-1.previous=at', 'O'): 1.277232,
#  ('w0.lower=+', 'O'): 0.444288,
#  ('w0.suffix3=+', 'O'): 0.444288,
#  ('w0.lower=splice', 'O'): 0.41939,
#  ('w1.post=site', 'O'): 1.667475,
#  ('w0.lower=site', 'O'): 0.825141,
#  ('w0.suffix3=ite', 'O'): 0.085409,
#  ('w0.lower=exon', 'O'): 0.245792,
#  ('w0.suffix3=xon', 'O'): 0.991297,
#  ('w0.lower=deletion', 'O'): 1.934227,
#  ('w1.post=this', 'O'): 0.140048,
#  ('w0.lower=this', 'O'): 1.017816,
#  ('w0.suffix3=his', 'O'): 1.055351,
#  ('w-1.previous=this', 'O'): 0.319821,
#  ('w1.post=from', 'O'): 0.297106,
#  ('w1.post=from', 'I-Disease'): -4.9e-05,
#  ('w0.suffix3=rom', 'B-Disease'): 0.02505,
#  ('w-1.previous=from', 'O'): -0.020282,
#  ('w-1.previous=from', 'B-Disease'): 0.368758,
#  ('w0.suffix3=RNA', 'O'): 1.654525,
#  ('w0.suffix3=nts', 'O'): 1.831763,
#  ('w0.suffix3=nts', 'I-Disease'): -0.149347,
#  ('w0.pos=VBZ', 'O'): 3.257183,
#  ('w1.post=only', 'O'): -0.100458,
#  ('w1.post=only', 'B-Disease'): 0.017306,
#  ('w0.lower=only', 'O'): -0.001324,
#  ('w0.lower=only', 'I-Disease'): 0.009283,
#  ('w0.suffix3=nly', 'I-Disease'): 0.006944,
#  ('w0.lower=frequent', 'O'): 0.020376,
#  ('w-1.previous=only', 'B-Disease'): 1.021994,
#  ('w-1.previous=reported', 'O'): -0.330027,
#  ('w-1.previous=reported', 'B-Disease'): 0.68122,
#  ('w-1.previous=although', 'O'): -0.018519,
#  ('w-1.previous=although', 'B-Disease'): 1.098209,
#  ('w0.lower=four', 'O'): 0.080648,
#  ('w0.suffix3=sed', 'O'): 0.075848,
#  ('w0.suffix3=ern', 'O'): 0.886771,
#  ('w0.pos=RBR', 'O'): 0.501215,
#  ('w-1.previous=more', 'O'): 0.053153,
#  ('w1.post=analysis', 'O'): 0.789429,
#  ('w0.lower=analysis', 'O'): 3.528226,
#  ('w1.post=has', 'O'): -0.268814,
#  ('w1.post=has', 'I-Disease'): 0.000372,
#  ('w0.lower=%', 'O'): 0.631354,
#  ('w0.suffix3=%', 'O'): 0.631354,
#  ('w0.suffix3=ast', 'O'): 0.659088,
#  ('w0.suffix3=ast', 'B-Disease'): -0.131107,
#  ('w0.suffix3=ast', 'I-Disease'): -0.016158,
#  ('w0.suffix3=ate', 'O'): 0.608033,
#  ('w0.suffix3=ate', 'B-Disease'): -0.499736,
#  ('w0.suffix3=ate', 'I-Disease'): -0.049593,
#  ('w1.post=n', 'O'): -0.14572,
#  ('w1.post=n', 'I-Disease'): 0.22872,
#  ('w0.lower=n', 'I-Disease'): 0.242739,
#  ('w1.post==', 'O'): 1.08625,
#  ('w0.lower==', 'O'): 0.242847,
#  ('w0.suffix3==', 'O'): 0.242847,
#  ('w-1.previous=n', 'I-Disease'): 0.006726,
#  ('w0.suffix3=ype', 'O'): 1.339327,
#  ('w0.suffix3=ype', 'I-Disease'): -0.26986,
#  ('w1.post=markers', 'O'): 0.052733,
#  ('w0.lower=markers', 'O'): 0.286852,
#  ('w0.suffix3=ers', 'O'): -0.406779,
#  ('w0.suffix3=ers', 'B-Disease'): 0.006156,
#  ('w0.suffix3=ers', 'I-Disease'): 0.116319,
#  ('w1.post=linked', 'O'): -0.377802,
#  ('w1.post=linked', 'I-Disease'): 0.468287,
#  ('w0.lower=linked', 'O'): -0.408463,
#  ('w0.lower=linked', 'I-Disease'): 0.473006,
#  ('w0.suffix3=ked', 'O'): 0.034129,
#  ('w0.suffix3=ked', 'I-Disease'): 0.455929,
#  ('w-1.previous=linked', 'O'): -0.393205,
#  ('w-1.previous=linked', 'B-Disease'): -1.461624,
#  ('w-1.previous=linked', 'I-Disease'): 1.493453,
#  ('w0.suffix3=hin', 'O'): 0.000873,
#  ('w0.suffix3=tle', 'O'): -0.155076,
#  ('w0.suffix3=nce', 'O'): 1.24404,
#  ('w0.suffix3=nce', 'B-Disease'): -0.469695,
#  ('w0.lower=most', 'O'): 0.038148,
#  ('w0.suffix3=ost', 'O'): 0.862858,
#  ('w-1.previous=most', 'B-Disease'): 0.003138,
#  ('w0.lower=these', 'O'): 0.155721,
#  ('w0.suffix3=ese', 'O'): 0.001671,
#  ('w-1.previous=these', 'B-Disease'): 0.066516,
#  ('w0.suffix3=der', 'O'): -0.041005,
#  ('w0.suffix3=der', 'I-Disease'): 0.812848,
#  ('w0.suffix3=ect', 'B-Disease'): -0.356316,
#  ('w1.post=within', 'O'): 0.090544,
#  ('w1.post=within', 'I-Disease'): -0.046899,
#  ('w0.lower=similar', 'O'): 1.59556,
#  ('w0.suffix3=lar', 'O'): -0.343083,
#  ('w0.suffix3=lar', 'B-Disease'): 0.155038,
#  ('w0.suffix3=lar', 'I-Disease'): 0.463749,
#  ('w-1.previous=similar', 'O'): 0.203526,
#  ('w0.lower=that', 'O'): 0.712703,
#  ('w0.suffix3=hat', 'O'): 0.739597,
#  ('w-1.previous=that', 'B-Disease'): 0.708853,
#  ('w1.post=mutations', 'O'): -0.148698,
#  ('w1.post=mutations', 'B-Disease'): 0.646761,
#  ('w1.post=mutations', 'I-Disease'): -0.013113,
#  ('w0.lower=mutations', 'O'): 3.474735,
#  ('w0.suffix3=age', 'O'): 0.204388,
#  ('w0.suffix3=age', 'B-Disease'): -1.040346,
#  ('w0.suffix3=age', 'I-Disease'): 0.002303,
#  ('w1.post=related', 'O'): 0.361131,
#  ('w0.lower=related', 'O'): 0.000526,
#  ('w-1.previous=related', 'B-Disease'): 0.001458,
#  ('w-1.previous=all', 'B-Disease'): 0.29647,
#  ('w0.suffix3=ial', 'O'): -0.592878,
#  ('w0.suffix3=ial', 'B-Disease'): 1.118355,
#  ('w0.suffix3=ial', 'I-Disease'): 0.004731,
#  ('w-1.previous=endometrial', 'I-Disease'): 1.266402,
#  ('w1.post=ovarian', 'O'): 0.008921,
#  ('w1.post=ovarian', 'B-Disease'): -0.736105,
#  ('w1.post=ovarian', 'I-Disease'): 0.639541,
#  ('w0.lower=ovarian', 'O'): -0.372892,
#  ('w0.lower=ovarian', 'B-Disease'): 0.448116,
#  ('w1.post=cancers', 'O'): -1.719292,
#  ('w1.post=cancers', 'B-Disease'): 0.359074,
#  ('w1.post=cancers', 'I-Disease'): 0.154054,
#  ('w0.lower=cancers', 'B-Disease'): 6.032881,
#  ('w0.lower=cancers', 'I-Disease'): 4.601483,
#  ('w-1.previous=ovarian', 'I-Disease'): 4.42963,
#  ('w-1.previous=cancers', 'O'): 2.427128,
#  ('w0.lower=carriers', 'O'): 1.628819,
#  ('w1.post=patients', 'O'): -1.487695,
#  ('w1.post=patients', 'B-Disease'): 1.209737,
#  ('w1.post=patients', 'I-Disease'): 0.755965,
#  ('w0.lower=patients', 'O'): 2.902626,
#  ('w0.suffix3=ned', 'B-Disease'): 0.531017,
#  ('w1.post=were', 'O'): -0.554841,
#  ('w1.post=were', 'B-Disease'): 0.121793,
#  ('w1.post=were', 'I-Disease'): 0.704949,
#  ('w0.lower=were', 'O'): 0.370309,
#  ('w0.lower=risk', 'O'): 0.26382,
#  ('w0.suffix3=isk', 'O'): 0.26382,
#  ('w-1.previous=risk', 'O'): 0.601556,
#  ('w0.suffix3=her', 'O'): 0.323872,
#  ('w0.suffix3=her', 'B-Disease'): -0.419412,
#  ('w1.post=p', 'O'): -0.170566,
#  ('w1.post=p', 'I-Disease'): 0.151275,
#  ('w0.lower=p', 'I-Disease'): 0.370882,
#  ('w1.post=<', 'O'): 0.016662,
#  ('w-1.previous=p', 'O'): 0.112932,
#  ('w-1.previous=.', 'O'): -1.322076,
#  ('w-1.previous=.', 'B-Disease'): -0.639513,
#  ('w-1.previous=.', 'I-Disease'): 2.986107,
#  ('w0.suffix3=han', 'O'): -0.018628,
#  ('w0.suffix3=han', 'I-Disease'): 0.186407,
#  ('w-1.previous=than', 'O'): -0.705167,
#  ('w-1.previous=than', 'B-Disease'): 0.044301,
#  ('w-1.previous=high', 'B-Disease'): -0.099463,
#  ('w-1.previous=high', 'I-Disease'): 2.2e-05,
#  ('w0.suffix3=sal', 'O'): -1.882078,
#  ('w0.suffix3=sal', 'I-Disease'): 0.075061,
#  ('w0.suffix3=mes', 'O'): 0.310993,
#  ('w0.lower=susceptibility', 'O'): 1.773733,
#  ('w0.suffix3=ity', 'O'): -0.023201,
#  ('w0.suffix3=ity', 'B-Disease'): 0.008728,
#  ('w0.suffix3=ity', 'I-Disease'): 0.001623,
#  ('w1.post=onset', 'I-Disease'): 0.014772,
#  ('w0.suffix3=set', 'O'): 0.56726,
#  ('w-1.previous=onset', 'O'): -0.785424,
#  ('w-1.previous=onset', 'B-Disease'): 1.39549,
#  ('w-1.previous=onset', 'I-Disease'): -0.273488,
#  ('w0.lower=huntington', 'O'): -0.053139,
#  ('w0.lower=huntington', 'B-Disease'): 1.037937,
#  ('w0.suffix3=ton', 'B-Disease'): 0.277181,
#  ('w1.post=disease', 'O'): -0.781225,
#  ('w1.post=disease', 'B-Disease'): 0.652045,
#  ('w1.post=disease', 'I-Disease'): -0.226714,
#  ('w0.lower=disease', 'O'): -0.596468,
#  ('w0.lower=disease', 'I-Disease'): 2.454003,
#  ('w-1.previous=huntington', 'O'): -0.892141,
#  ('w-1.previous=huntington', 'I-Disease'): 0.958719,
#  ('w-1.previous=disease', 'O'): 0.601412,
#  ('w-1.previous=disease', 'B-Disease'): 1.152507,
#  ('w-1.previous=disease', 'I-Disease'): -1.385787,
#  ('w0.lower=normal', 'O'): 0.993968,
#  ('w0.suffix3=mal', 'O'): -0.005807,
#  ('w0.suffix3=mal', 'B-Disease'): 0.432192,
#  ('w0.suffix3=mal', 'I-Disease'): -1.246493,
#  ('w-1.previous=normal', 'O'): 1e-05,
#  ('w-1.previous=normal', 'B-Disease'): -0.12778,
#  ('w0.suffix3=eat', 'O'): 0.354433,
#  ('w0.lower=hd', 'B-Disease'): 3.896638,
#  ('w0.suffix3=HD', 'B-Disease'): 3.896638,
#  ('w-1.previous=hd', 'O'): 1.840436,
#  ('w1.post=is', 'O'): -0.459155,
#  ('w1.post=is', 'B-Disease'): -0.001293,
#  ('w1.post=is', 'I-Disease'): 0.529431,
#  ('w0.lower=is', 'O'): 0.462071,
#  ('w0.suffix3=is', 'O'): 0.462071,
#  ('w-1.previous=is', 'O'): 0.278428,
#  ('w0.lower=be', 'O'): 0.143435,
#  ('w0.suffix3=be', 'O'): 0.143435,
#  ('w-1.previous=be', 'O'): -0.000627,
#  ('w-1.previous=be', 'B-Disease'): 0.045208,
#  ('w1.post=an', 'O'): 0.271044,
#  ('w0.suffix3=ded', 'O'): -0.154742,
#  ('w0.suffix3=ded', 'I-Disease'): 0.478977,
#  ('w-1.previous=an', 'O'): -0.165078,
#  ('w-1.previous=an', 'B-Disease'): 0.491277,
#  ('w0.lower=other', 'O'): 0.859695,
#  ('w0.lower=neurological', 'B-Disease'): 0.340689,
#  ('w0.suffix3=cal', 'O'): -0.166538,
#  ('w0.suffix3=cal', 'B-Disease'): 0.707114,
#  ('w0.suffix3=cal', 'I-Disease'): 0.298318,
#  ('w-1.previous=other', 'O'): -0.076607,
#  ('w-1.previous=other', 'B-Disease'): 0.905755,
#  ('w1.post=diseases', 'O'): -0.987393,
#  ('w1.post=diseases', 'B-Disease'): 1.317755,
#  ('w0.lower=diseases', 'O'): -1.016724,
#  ('w0.lower=diseases', 'I-Disease'): 1.786431,
#  ('w0.suffix3=ses', 'O'): 0.293424,
#  ('w-1.previous=neurological', 'O'): -0.629035,
#  ('w-1.previous=neurological', 'I-Disease'): 1.380688,
#  ('w0.lower=who', 'O'): 0.004371,
#  ('w0.suffix3=who', 'O'): 0.004134,
#  ('w0.pos=WP', 'O'): 0.418975,
#  ('w0.lower=clinical', 'O'): 1.435237,
#  ('w0.lower=clinical', 'B-Disease'): -0.194164,
#  ('w-1.previous=clinical', 'O'): 0.215887,
#  ('w1.post=inherited', 'O'): -0.413051,
#  ('w1.post=inherited', 'B-Disease'): 0.399038,
#  ('w0.lower=inherited', 'O'): -0.69561,
#  ('w0.lower=inherited', 'I-Disease'): 0.518021,
#  ('w-1.previous=inherited', 'O'): -2.926766,
#  ('w-1.previous=inherited', 'I-Disease'): 1.01223,
#  ('w0.lower=male', 'B-Disease'): 0.023057,
#  ('w0.suffix3=ale', 'O'): 0.279833,
#  ('w0.suffix3=ale', 'I-Disease'): -0.328159,
#  ('w-1.previous=male', 'B-Disease'): -0.142833,
#  ('w-1.previous=male', 'I-Disease'): 0.530861,
#  ('w0.lower=show', 'O'): 0.215429,
#  ('w0.suffix3=how', 'O'): 0.222329,
#  ('w0.lower=associated', 'O'): 0.401476,
#  ('w0.suffix3=ier', 'O'): 0.752286,
#  ('w0.lower=such', 'O'): 0.002419,
#  ('w0.suffix3=uch', 'O'): 0.003376,
#  ('w0.suffix3=not', 'O'): 0.197266,
#  ('w0.suffix3=any', 'O'): 0.64259,
#  ('w-1.previous=any', 'O'): -0.321604,
#  ('w-1.previous=any', 'B-Disease'): 1.047025,
#  ('w0.suffix3=pes', 'O'): 1.552936,
#  ('w0.pos=PRP$', 'O'): 1.523698,
#  ('w0.lower=suggest', 'O'): 0.854577,
#  ('w0.suffix3=est', 'I-Disease'): -0.282855,
#  ('w0.suffix3=rse', 'O'): 0.298734,
#  ('w0.lower=neurodegeneration', 'B-Disease'): 5.410138,
#  ('w0.suffix3=low', 'O'): 0.779045,
#  ('w0.suffix3=nes', 'O'): 0.807683,
#  ('w0.suffix3=nes', 'I-Disease'): -0.012701,
#  ('w0.suffix3=cts', 'O'): -1.10069,
#  ('w0.suffix3=cts', 'B-Disease'): 0.342969,
#  ('w0.suffix3=cts', 'I-Disease'): 0.214433,
#  ('w0.lower=familial', 'B-Disease'): 1.167767,
#  ('w0.lower=familial', 'I-Disease'): -0.015193,
#  ('w1.post=deficiency', 'O'): -0.520653,
#  ('w1.post=deficiency', 'B-Disease'): 0.55739,
#  ('w1.post=deficiency', 'I-Disease'): -0.16302,
#  ('w0.lower=deficiency', 'O'): -3.045873,
#  ('w0.lower=deficiency', 'B-Disease'): 0.39443,
#  ('w0.lower=deficiency', 'I-Disease'): 0.649491,
#  ('w-1.previous=familial', 'O'): -0.310366,
#  ('w-1.previous=familial', 'I-Disease'): 1.534253,
#  ('w-1.previous=deficiency', 'O'): 0.191976,
#  ('w-1.previous=deficiency', 'I-Disease'): -0.079239,
#  ('w1.post=component', 'I-Disease'): 3.204291,
#  ('w0.lower=component', 'O'): -0.617322,
#  ('w0.lower=component', 'I-Disease'): 1.126341,
#  ('w-1.previous=component', 'O'): -0.92847,
#  ('w-1.previous=component', 'I-Disease'): 0.969199,
#  ('w1.post=complement', 'B-Disease'): -0.122072,
#  ('w1.post=complement', 'I-Disease'): 0.399808,
#  ('w0.lower=complement', 'O'): -2.058346,
#  ('w0.lower=complement', 'B-Disease'): 0.115804,
#  ('w-1.previous=complement', 'O'): 0.10881,
#  ('w-1.previous=complement', 'I-Disease'): 0.125682,
#  ('w0.lower=recurrent', 'O'): 0.754989,
#  ('w-1.previous=recurrent', 'B-Disease'): 1.270683,
#  ('w-1.previous=recurrent', 'I-Disease'): -0.049079,
#  ('w1.post=infections', 'O'): -0.537154,
#  ('w1.post=infections', 'B-Disease'): 0.421835,
#  ('w0.lower=infections', 'O'): -0.995968,
#  ('w0.lower=infections', 'I-Disease'): 1.091154,
#  ('w1.post=due', 'O'): -0.675079,
#  ('w1.post=due', 'I-Disease'): 0.360954,
#  ('w1.post=neisseria', 'O'): -0.09686,
#  ('w0.lower=neisseria', 'I-Disease'): 0.357072,
#  ('w0.suffix3=ria', 'O'): -3.096862,
#  ('w0.suffix3=ria', 'B-Disease'): 1.600236,
#  ('w0.suffix3=ria', 'I-Disease'): 0.285869,
#  ('w0.lower=serum', 'O'): 0.907738,
#  ('w0.suffix3=rum', 'O'): 0.08454,
#  ('w-1.previous=serum', 'O'): 0.011663,
#  ('w0.suffix3=ear', 'O'): 0.067733,
#  ('w1.post=infection', 'O'): -1.478839,
#  ('w1.post=infection', 'B-Disease'): 0.011061,
#  ('w0.lower=infection', 'O'): -1.069172,
#  ('w0.lower=infection', 'I-Disease'): 1.607819,
#  ('w-1.previous=gonococcal', 'I-Disease'): 1.674911,
#  ('w-1.previous=infection', 'O'): 0.215125,
#  ('w0.suffix3=ory', 'O'): 0.417456,
#  ('w0.lower=meningococcal', 'B-Disease'): 1.865077,
#  ('w1.post=meningitis', 'O'): -1.158395,
#  ('w1.post=meningitis', 'B-Disease'): 0.440707,
#  ('w0.lower=meningitis', 'I-Disease'): 1.2495,
#  ('w0.suffix3=tis', 'O'): -4.055577,
#  ('w0.suffix3=tis', 'B-Disease'): 1.830598,
#  ('w0.suffix3=tis', 'I-Disease'): 1.0205,
#  ('w-1.previous=meningitis', 'O'): 1.094102,
#  ('w1.post=arthritis', 'B-Disease'): 0.248,
#  ('w0.suffix3=ild', 'O'): 1.866845,
#  ('w0.suffix3=ild', 'B-Disease'): -0.752622,
#  ('w0.lower=found', 'O'): 0.448403,
#  ('w0.suffix3=und', 'O'): 0.781838,
#  ('w0.suffix3=ack', 'I-Disease'): 0.001292,
#  ('w1.post=hemolytic', 'B-Disease'): -0.249042,
#  ('w1.post=hemolytic', 'I-Disease'): 0.01771,
#  ('w0.suffix3=tic', 'O'): -0.470218,
#  ('w0.suffix3=tic', 'B-Disease'): 1.277192,
#  ('w0.suffix3=tic', 'I-Disease'): -0.011946,
#  ('w-1.previous=hemolytic', 'I-Disease'): 0.178871,
#  ('w0.lower=activity', 'O'): 1.128521,
#  ('w0.lower=activity', 'I-Disease'): -0.015077,
#  ('w1.post=c7', 'B-Disease'): -0.445039,
#  ('w1.post=c7', 'I-Disease'): 1.051306,
#  ('w0.lower=c7', 'O'): -0.368005,
#  ('w0.lower=c7', 'I-Disease'): 0.3616,
#  ('w0.suffix3=C7', 'O'): -0.368005,
#  ('w0.suffix3=C7', 'I-Disease'): 0.3616,
#  ('w-1.previous=c7', 'I-Disease'): 0.195457,
#  ('w1.post=or', 'O'): -1.520898,
#  ('w1.post=or', 'I-Disease'): 0.369631,
#  ('w0.lower=or', 'O'): 0.349009,
#  ('w0.lower=or', 'I-Disease'): -0.073847,
#  ('w0.suffix3=or', 'O'): 0.349009,
#  ('w0.suffix3=or', 'I-Disease'): -0.073847,
#  ('w-1.previous=or', 'O'): -0.395426,
#  ('w-1.previous=or', 'B-Disease'): 0.763047,
#  ('w-1.previous=or', 'I-Disease'): -0.038204,
#  ('w0.suffix3=eas', 'O'): -0.002826,
#  ('w0.suffix3=eas', 'I-Disease'): 1.031563,
#  ('w-1.previous=against', 'O'): -0.043518,
#  ('w-1.previous=against', 'B-Disease'): 0.378812,
#  ('w0.suffix3=ell', 'O'): 0.410735,
#  ('w0.suffix3=ell', 'I-Disease'): 0.027373,
#  ('w0.lower=absence', 'O'): -0.531568,
#  ('w0.lower=absence', 'B-Disease'): 0.365846,
#  ('w-1.previous=absence', 'O'): -0.973651,
#  ('w-1.previous=absence', 'I-Disease'): 1.921628,
#  ('w1.post=could', 'O'): 0.050278,
#  ('w0.lower=on', 'O'): 0.121921,
#  ('w0.suffix3=on', 'O'): 0.111216,
#  ('w0.lower=basis', 'O'): 2.318755,
#  ('w-1.previous=basis', 'O'): 1.027625,
#  ('w0.lower=complete', 'O'): -0.040223,
#  ('w0.lower=complete', 'I-Disease'): 0.732787,
#  ('w0.suffix3=ete', 'I-Disease'): 0.062674,
#  ('w-1.previous=complete', 'O'): -0.63095,
#  ('w-1.previous=complete', 'I-Disease'): 0.436583,
#  ('w0.lower=also', 'O'): 0.053222,
#  ('w0.suffix3=lso', 'O'): 0.053222,
#  ('w0.suffix3=one', 'I-Disease'): 0.032403,
#  ('w-1.previous=had', 'O'): -0.049943,
#  ('w-1.previous=had', 'B-Disease'): 0.787913,
#  ('w-1.previous=clinically', 'O'): 0.861943,
#  ('w0.suffix3=son', 'O'): -0.438751,
#  ('w0.suffix3=son', 'B-Disease'): 1.373728,
#  ('w0.lower=hla', 'O'): 0.085378,
#  ('w0.suffix3=HLA', 'O'): 0.085378,
#  ('w1.post=family', 'O'): -0.05006,
#  ('w1.post=family', 'B-Disease'): 0.008259,
#  ('w0.lower=family', 'O'): 0.541285,
#  ('w0.suffix3=ily', 'O'): 1.026457,
#  ('w0.lower=genetic', 'O'): 0.374306,
#  ('w0.lower=genetic', 'B-Disease'): -0.384614,
#  ('w0.lower=linkage', 'O'): 0.491525,
#  ('w-1.previous=genetic', 'O'): -1.002607,
#  ('w-1.previous=genetic', 'B-Disease'): 0.035824,
#  ('w-1.previous=genetic', 'I-Disease'): 0.534393,
#  ('w-1.previous=linkage', 'O'): 0.155272,
#  ('w0.lower=major', 'O'): 0.071158,
#  ('w0.suffix3=jor', 'O'): 0.071158,
#  ('w0.lower=loci', 'O'): 0.269718,
#  ('w0.suffix3=oci', 'O'): 0.710679,
#  ('w0.lower=cases', 'O'): 1.661141,
#  ('w0.lower=suggests', 'O'): 0.340755,
#  ('w0.suffix3=sts', 'O'): 0.028237,
#  ('w0.suffix3=sts', 'I-Disease'): -0.278513,
#  ('w0.suffix3=ant', 'O'): 0.629877,
#  ('w0.suffix3=ant', 'I-Disease'): -0.400224,
#  ('w0.suffix3=nse', 'O'): 0.043847,
#  ('w0.suffix3=air', 'O'): 0.371793,
#  ('w1.post=hypoplasia', 'B-Disease'): 0.429418,
#  ('w0.lower=hypoplasia', 'I-Disease'): 1.234395,
#  ('w0.suffix3=sia', 'O'): -2.67264,
#  ('w0.suffix3=sia', 'I-Disease'): 1.988063,
#  ('w1.post=among', 'B-Disease'): 0.177659,
#  ('w0.lower=among', 'O'): 0.321829,
#  ('w-1.previous=among', 'O'): -0.001343,
#  ('w-1.previous=among', 'B-Disease'): 0.12127,
#  ('w0.lower=chh', 'B-Disease'): 2.214874,
#  ('w0.suffix3=CHH', 'B-Disease'): 2.214874,
#  ('w0.lower=study', 'O'): 0.401798,
#  ('w0.suffix3=udy', 'O'): 0.088363,
#  ('w0.suffix3=out', 'O'): 0.052992,
#  ('w0.suffix3=ree', 'O'): 0.0149,
#  ('w0.suffix3=ide', 'O'): 0.140111,
#  ('w0.suffix3=gic', 'O'): -0.231817,
#  ('w0.suffix3=gic', 'B-Disease'): 0.449586,
#  ('w0.lower=population', 'O'): 0.637809,
#  ('w0.suffix3=ter', 'O'): 0.099494,
#  ('w0.suffix3=ter', 'B-Disease'): -0.013384,
#  ('w0.lower=underwent', 'O'): 0.000477,
#  ('w-1.previous=underwent', 'O'): 0.059534,
#  ('w0.lower=results', 'O'): 0.672829,
#  ('w0.suffix3=ess', 'O'): -1.489246,
#  ('w0.suffix3=ess', 'B-Disease'): 0.132926,
#  ('w-1.previous=significant', 'B-Disease'): 0.000313,
#  ('w0.suffix3=een', 'O'): 0.933285,
#  ('w1.post=6', 'I-Disease'): 0.071511,
#  ('w0.lower=6', 'O'): -0.237251,
#  ('w0.lower=6', 'I-Disease'): 0.451608,
#  ('w0.suffix3=6', 'O'): -0.237251,
#  ('w0.suffix3=6', 'I-Disease'): 0.451608,
#  ('w-1.previous=6', 'O'): -0.027557,
#  ('w-1.previous=6', 'B-Disease'): -0.097354,
#  ('w-1.previous=6', 'I-Disease'): 0.273496,
#  ('w1.post=hodgkins', 'O'): -0.003217,
#  ('w1.post=hodgkins', 'I-Disease'): 0.029527,
#  ('w0.lower=hodgkins', 'I-Disease'): 0.00496,
#  ('w1.post=lymphoma', 'B-Disease'): 0.038717,
#  ('w0.lower=lymphoma', 'B-Disease'): -0.009463,
#  ('w-1.previous=hodgkins', 'I-Disease'): 0.463328,
#  ('w-1.previous=lymphoma', 'O'): 0.000162,
#  ('w1.post=cell', 'O'): -0.336736,
#  ('w1.post=cell', 'B-Disease'): 0.067733,
#  ('w1.post=cell', 'I-Disease'): 0.18703,
#  ('w0.lower=cell', 'O'): 0.332543,
#  ('w0.lower=cell', 'I-Disease'): 0.147417,
#  ('w-1.previous=cell', 'B-Disease'): -0.013019,
#  ('w-1.previous=cell', 'I-Disease'): 0.047392,
#  ('w0.suffix3=fer', 'O'): -0.005014,
#  ('w0.suffix3=fer', 'I-Disease'): 0.043349,
#  ('w0.suffix3=rms', 'O'): 0.055795,
#  ('w-1.previous=especially', 'O'): -1.359164,
#  ('w1.post=phenotype', 'O'): -1.781096,
#  ('w1.post=phenotype', 'B-Disease'): 1.093247,
#  ('w1.post=phenotype', 'I-Disease'): 0.020765,
#  ('w0.lower=phenotype', 'O'): 1.136963,
#  ('w0.lower=phenotype', 'I-Disease'): -0.459126,
#  ('w1.post=dehydrogenase', 'O'): -0.019966,
#  ('w1.post=dehydrogenase', 'I-Disease'): 0.022525,
#  ('w0.lower=dehydrogenase', 'O'): -0.006673,
#  ('w0.lower=dehydrogenase', 'I-Disease'): 0.08306,
#  ('w-1.previous=dehydrogenase', 'O'): -0.841138,
#  ('w-1.previous=dehydrogenase', 'I-Disease'): 1.868196,
#  ('w0.lower=autosomal', 'O'): -0.17049,
#  ('w0.lower=autosomal', 'B-Disease'): 0.432966,
#  ('w0.lower=recessive', 'O'): -0.118611,
#  ('w0.lower=recessive', 'I-Disease'): 0.169748,
#  ('w-1.previous=autosomal', 'O'): -0.040367,
#  ('w-1.previous=autosomal', 'B-Disease'): -0.885647,
#  ('w-1.previous=autosomal', 'I-Disease'): 1.283062,
#  ('w-1.previous=recessive', 'O'): -0.384736,
#  ('w-1.previous=recessive', 'I-Disease'): 0.905049,
#  ('w1.post=homozygous', 'O'): 0.048236,
#  ('w0.lower=homozygous', 'O'): 1.468653,
#  ('w0.lower=homozygous', 'B-Disease'): -0.042721,
#  ('w1.post=deficient', 'O'): -0.516328,
#  ('w1.post=deficient', 'I-Disease'): 0.003253,
#  ('w0.lower=deficient', 'O'): -3.657906,
#  ('w0.lower=deficient', 'B-Disease'): 0.367123,
#  ('w0.lower=deficient', 'I-Disease'): 0.609494,
#  ...}

# %%
for i in state_features.keys():
    if(("w0.pos" in i[0])or ("w0.tit" in i[0] )):
        print(i)
# Out:
# ('w0.pos=NN', 'O')
# ('w0.pos=NN', 'B-Disease')
# ('w0.pos=NN', 'I-Disease')
# ('w0.tit=True', 'O')
# ('w0.tit=True', 'B-Disease')
# ('w0.tit=True', 'I-Disease')
# ('w0.pos=IN', 'O')
# ('w0.pos=IN', 'B-Disease')
# ('w0.pos=IN', 'I-Disease')
# ('w0.tit=False', 'O')
# ('w0.tit=False', 'B-Disease')
# ('w0.tit=False', 'I-Disease')
# ('w0.pos=,', 'O')
# ('w0.pos=,', 'I-Disease')
# ('w0.pos=DT', 'O')
# ('w0.pos=DT', 'B-Disease')
# ('w0.pos=DT', 'I-Disease')
# ('w0.pos=JJ', 'O')
# ('w0.pos=JJ', 'B-Disease')
# ('w0.pos=JJ', 'I-Disease')
# ('w0.pos=NNS', 'O')
# ('w0.pos=NNS', 'B-Disease')
# ('w0.pos=NNS', 'I-Disease')
# ('w0.pos=.', 'O')
# ('w0.pos=.', 'I-Disease')
# ('w0.pos=(', 'O')
# ('w0.pos=(', 'I-Disease')
# ('w0.pos=)', 'O')
# ('w0.pos=)', 'I-Disease')
# ('w0.pos=:', 'O')
# ('w0.pos=:', 'I-Disease')
# ('w0.pos=VBG', 'O')
# ('w0.pos=VBG', 'B-Disease')
# ('w0.pos=VBG', 'I-Disease')
# ('w0.pos=CD', 'O')
# ('w0.pos=CD', 'I-Disease')
# ('w0.pos=CC', 'O')
# ('w0.pos=CC', 'I-Disease')
# ('w0.pos=TO', 'O')
# ('w0.pos=TO', 'I-Disease')
# ('w0.pos=PRP', 'O')
# ('w0.pos=VBN', 'O')
# ('w0.pos=VBN', 'B-Disease')
# ('w0.pos=VBN', 'I-Disease')
# ('w0.pos=RB', 'O')
# ('w0.pos=RB', 'B-Disease')
# ('w0.pos=RB', 'I-Disease')
# ('w0.pos=WDT', 'O')
# ('w0.pos=VBD', 'O')
# ('w0.pos=VBD', 'I-Disease')
# ('w0.pos=VBP', 'O')
# ('w0.pos=NNP', 'O')
# ('w0.pos=NNP', 'B-Disease')
# ('w0.pos=MD', 'O')
# ('w0.pos=VB', 'O')
# ('w0.pos=VB', 'B-Disease')
# ('w0.pos=VB', 'I-Disease')
# ('w0.pos=VBZ', 'O')
# ('w0.pos=RBR', 'O')
# ('w0.pos=WP', 'O')
# ('w0.pos=PRP$', 'O')
# ("w0.pos=''", 'I-Disease')

# %% [markdown]
# here the model did not discard the features that i have included
# w0.tit and w0.pos is available in the state_features

# %% [markdown]
# ## Question 6

# %%
def agg_tok_lvl(t):
    if("B-Disease" in t):
        return 1
    else:

        return 0
    
test_arr_gt=[]    
for i in test_tags:
    test_arr_gt.append(agg_tok_lvl(i))
    
test_arr_pred=[]    
for i in y_pred:
    test_arr_pred.append(agg_tok_lvl(i))

# %%
len(test_arr_pred)
# Out:
# 940

# %%
from sklearn.metrics import precision_score,recall_score
precision = precision_score(test_arr_gt, test_arr_pred)
recall = recall_score(test_arr_gt, test_arr_pred)

# %%
print("the precision is",precision)
# Out:
# the precision is 0.963855421686747

# %%
print("the recall is",recall)
# Out:
# the recall is 0.8905380333951762
